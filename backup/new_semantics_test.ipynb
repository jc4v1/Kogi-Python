# %%
from Semantics.istar_processor import read_istar_model

# goal_model_path = "content/test_new_semantics/goalModel.txt"
# goal_model_path = "tests/data/gm_dep_quality_quality_goal.txt"
goal_model_path = "tests/data/gm_break1.txt"
# goal_model_path = "tests/data/gm_goal_dep.txt"
# goal_model_path = "tests/data/gm_GoCCvA.txt"
# goal_model_path = "content/gm_two_deps.txt"


goal_model = read_istar_model(str(goal_model_path), qualified=False)
goal_model.kogi = False

from Ui.interface import SingleStepInterfaceBuilder, WhatIfInterfaceBuilder
interface = WhatIfInterfaceBuilder(goal_model).create_interface()
display(interface)

goal_model2 = read_istar_model(str(goal_model_path), qualified=False)
goal_model2.kogi = False

from Ui.interface import WhatIfInterfaceBuilder
interface = SingleStepInterfaceBuilder(goal_model2).create_interface()
display(interface)
