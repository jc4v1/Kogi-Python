# %% [markdown]
# ## Required imports

# %%
from Semantics.istar_processor import read_istar_model
from Semantics.petri_net_processor import read_petri_net
from Semantics.petri_net_processor import PetriNet
from Semantics.dcr import read_dcr
from Semantics.event_mapping_from_csv import read_event_mapping_csv
from Ui.interface import InterfaceBuilder, WhatIfInterfaceBuilder, analyse_models
from Semantics.transition_system import combine_goal_model_and_petri_net
from Semantics.transition_system import CombinedTransitionSystem
from scripts.sanitize_pnml import sanitize
from Semantics.event_mapping_from_csv import event_mapping_for_petri_net
import pm4py

# %%
goal_model = read_istar_model('Data/bpmn/goal_model.txt')
bpmn_model = pm4py.read_bpmn("Data/bpmn/process_model.bpmn")
mapping_org = read_event_mapping_csv("Data/bpmn/map.csv")

net, initial_marking, final_marking = pm4py.convert_to_petri_net(bpmn_model)
petri_net = PetriNet(net,initial_marking,final_marking,{})

mapping = event_mapping_for_petri_net(mapping_org,petri_net)   

analyse_models(goal_model, petri_net, mapping)
# Out:
# Goal Model LTS reachable states and transitions: (369, 4059)
# Process Model LTS reachable states and transitions: (9, 10)
# Combined LTS reachable states and transitions: (10, 10)
#
# Goal Model Goals and Tasks: ['G1', 'G2', 'G3', 'T1', 'T2', 'T4', 'T5', 'T6', 'T7', 'T8', 'T3']
# Goal Model Qualities: {'Q1'}
#
# Combined LTS Actions: {'sid-38162DD8-8327-4B14-A20E-FB8C4941DF72', 'sid-BDB258CA-2777-4814-BDE5-E671AC4EBF4F', 'sid-13EFD34F-F605-4870-80C9-6837C05F8599', 'sid-06EBC4FA-101D-410B-884F-38FCAB182511', 'sid-04E2BE1E-CB0E-4FB4-AC6F-307E5993135F', 'sid-DCA3844E-4A80-4CD3-A3F4-F2D5010E9022', 'sid-BC760514-61FF-475B-AD4C-A8F3BBE4CD1D', 'sid-D615ECAD-3E46-44C2-87E3-F3C68CE5AADD'}
#
# Event Mapping {'sid-BC760514-61FF-475B-AD4C-A8F3BBE4CD1D': [['T1']], 'sid-13EFD34F-F605-4870-80C9-6837C05F8599': [['T2']], 'sid-DCA3844E-4A80-4CD3-A3F4-F2D5010E9022': [['T4']], 'sid-06EBC4FA-101D-410B-884F-38FCAB182511': [['T7']], 'sid-BDB258CA-2777-4814-BDE5-E671AC4EBF4F': [['T6']], 'sid-38162DD8-8327-4B14-A20E-FB8C4941DF72': [['T3']], 'sid-04E2BE1E-CB0E-4FB4-AC6F-307E5993135F': [['T5']], 'sid-D615ECAD-3E46-44C2-87E3-F3C68CE5AADD': [['T8']]}
#
# Stability: False
# Counter-examples (2):
#   ('sid-BDB258CA-2777-4814-BDE5-E671AC4EBF4F', 'sid-38162DD8-8327-4B14-A20E-FB8C4941DF72', 'sid-13EFD34F-F605-4870-80C9-6837C05F8599', 'sid-DCA3844E-4A80-4CD3-A3F4-F2D5010E9022', 'sid-04E2BE1E-CB0E-4FB4-AC6F-307E5993135F')
#   ('sid-BDB258CA-2777-4814-BDE5-E671AC4EBF4F', 'sid-13EFD34F-F605-4870-80C9-6837C05F8599', 'sid-38162DD8-8327-4B14-A20E-FB8C4941DF72', 'sid-DCA3844E-4A80-4CD3-A3F4-F2D5010E9022', 'sid-04E2BE1E-CB0E-4FB4-AC6F-307E5993135F')
# Weak Compliance: False
# Counter-examples (4):
#   ('sid-BDB258CA-2777-4814-BDE5-E671AC4EBF4F', 'sid-38162DD8-8327-4B14-A20E-FB8C4941DF72', 'sid-13EFD34F-F605-4870-80C9-6837C05F8599', 'sid-DCA3844E-4A80-4CD3-A3F4-F2D5010E9022', 'sid-04E2BE1E-CB0E-4FB4-AC6F-307E5993135F')
#   ('sid-BDB258CA-2777-4814-BDE5-E671AC4EBF4F', 'sid-38162DD8-8327-4B14-A20E-FB8C4941DF72', 'sid-13EFD34F-F605-4870-80C9-6837C05F8599', 'sid-DCA3844E-4A80-4CD3-A3F4-F2D5010E9022', 'sid-04E2BE1E-CB0E-4FB4-AC6F-307E5993135F', 'sid-06EBC4FA-101D-410B-884F-38FCAB182511')
#   ('sid-BDB258CA-2777-4814-BDE5-E671AC4EBF4F', 'sid-38162DD8-8327-4B14-A20E-FB8C4941DF72', 'sid-13EFD34F-F605-4870-80C9-6837C05F8599', 'sid-DCA3844E-4A80-4CD3-A3F4-F2D5010E9022', 'sid-04E2BE1E-CB0E-4FB4-AC6F-307E5993135F', 'sid-06EBC4FA-101D-410B-884F-38FCAB182511', 'sid-BC760514-61FF-475B-AD4C-A8F3BBE4CD1D')
#   ... and 1 more counter-examples
