# %% [markdown]
# ## Required imports

# %%
from Semantics.istar_processor import read_istar_model
from Semantics.petri_net_processor import read_petri_net
from Semantics.dcr import read_dcr
from Semantics.event_mapping_from_csv import read_event_mapping_csv
from Ui.interface import InterfaceBuilder, WhatIfInterfaceBuilder, analyse_models
from Semantics.transition_system import combine_goal_model_and_petri_net
from Semantics.transition_system import CombinedTransitionSystem
from scripts.sanitize_pnml import sanitize

# %% [markdown]
# ## Running Example

# %% [markdown]
# Petri Net
#
# ![Petri Net](Data/example/petri_net.png)

# %% [markdown]
# Goal Model
#
# ![Goal Model](Data/example/goal_model.png)

# %% [markdown]
# Event Mapping
#
# ![Event Mapping](Data/example/map.jpg)

# %% [markdown]
# ### Non-Interactice

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")
petri_net = read_petri_net("Data/example/petri_net.pnml")
event_mapping = read_event_mapping_csv("Data/example/map.csv")

analyse_models(goal_model, petri_net, event_mapping)
# Out:
# Goal Model LTS reachable states and transitions: (20, 160)
# Petri Net LTS reachable states and transitions: (7, 8)
# Combined LTS reachable states and transitions: (11, 11)
#
# Goal Model Goals and Tasks: ['g4: Application closed', 'g1: Required documentation registered', 'g2: Application assessed', 'g3: Decision-making completed', 't1: Register application', 't4: Deny', 't2: Assess application', 't3: Approve']
# Goal Model Qualities: {'q1: Increase city business growth'}
#
# Combined LTS Actions: {'t2', 't6', 't4', 't5', 't8', 't3', 't1', 't7'}
#
# Event Mapping {'t1': [], 't2': [['t1: Register application']], 't3': [['t2: Assess application']], 't4': [], 't5': [], 't6': [['t3: Approve']], 't7': [['t4: Deny']], 't8': []}
#
# Stability: True
# Weak Compliance: False
# Counter-examples (2):
#   ('t1', 't2', 't3', 't5', 't7')
#   ('t1', 't2', 't3', 't5', 't7', 't8')

# %% [markdown]
# ### Interactive

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")
petri_net = read_petri_net("Data/example/petri_net.pnml")
event_mapping = read_event_mapping_csv("Data/example/map.csv")

interface = InterfaceBuilder(goal_model,petri_net=petri_net,event_mapping=event_mapping).create_interface()
display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# ### WhatIf Scenario

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")

interface = WhatIfInterfaceBuilder(goal_model).create_interface()
display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# ### DCR Graph as the process model
#
# The DCR from the paper. This not stable because I can make a quality that was true false again. But it is
# weakly compliant, as I can always satisfy the quality.
#
# ![DCR from paper](Data/example/dcr_paper.jpg)

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")
dcr = read_dcr("Data/example/dcr_paper.xml")
event_mapping = read_event_mapping_csv("Data/example/dcr_map.csv")

analyse_models(goal_model, dcr, event_mapping)
# Out:
# Goal Model LTS reachable states and transitions: (20, 160)
# Petri Net LTS reachable states and transitions: (19, 38)
# Combined LTS reachable states and transitions: (23, 46)
#
# Goal Model Goals and Tasks: ['g4: Application closed', 'g1: Required documentation registered', 'g2: Application assessed', 'g3: Decision-making completed', 't1: Register application', 't4: Deny', 't2: Assess application', 't3: Approve']
# Goal Model Qualities: {'q1: Increase city business growth'}
#
# Combined LTS Actions: {'Deny', 'Assess', 'Register', 'Approve'}
#
# Event Mapping {'Assess': [['t2: Assess application']], 'Approve': [['t3: Approve']], 'Deny': [['t4: Deny']], 'Register': [['t1: Register application']]}
#
# Stability: False
# Counter-examples (7):
#   ('Assess', 'Approve', 'Register', 'Deny')
#   ('Assess', 'Approve', 'Register', 'Assess', 'Deny')
#   ('Register', 'Assess', 'Approve', 'Register', 'Deny')
#   ('Assess', 'Register', 'Approve', 'Assess', 'Register', 'Deny')
#   ('Assess', 'Deny', 'Register', 'Assess', 'Approve', 'Register', 'Deny')
#   ('Assess', 'Deny', 'Register', 'Approve', 'Assess', 'Register', 'Deny')
#   ('Assess', 'Deny', 'Register', 'Assess', 'Approve', 'Register', 'Assess', 'Deny')
# Weak Compliance: True

# %% [markdown]
# To understand what is going on, one can open the DCR simulator on or DCR Graphs https://hugoalopez-dtu.github.io/dcr-js/ (read the file as a DCR Solutions XML) and execute the traces given as counter examples and also run the What-if interactive animation for the goal model.

# %%
interface = WhatIfInterfaceBuilder(goal_model).create_interface()
display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# This is an alternate version, where one cannot repeat the process. In this case, it is stable, because either we end in a satisfied quality and we are done. Or the quality is not satisfied, but then we are also done.
#
# The example, however, is not weakly compliant, as we can always get to a state where the quality is not satisfied and we have reached the end of the execution.
#
# ![DCR from paper fixed](Data/example/dcr_fixed.jpg)

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")
dcr = read_dcr("Data/example/dcr_fixed.xml")
event_mapping = read_event_mapping_csv("Data/example/dcr_map.csv")
analyse_models(goal_model, dcr, event_mapping)
# Out:
# Goal Model LTS reachable states and transitions: (20, 160)
# Petri Net LTS reachable states and transitions: (13, 16)
# Combined LTS reachable states and transitions: (13, 16)
#
# Goal Model Goals and Tasks: ['g4: Application closed', 'g1: Required documentation registered', 'g2: Application assessed', 'g3: Decision-making completed', 't1: Register application', 't4: Deny', 't2: Assess application', 't3: Approve']
# Goal Model Qualities: {'q1: Increase city business growth'}
#
# Combined LTS Actions: {'Deny', 'Assess', 'Register', 'Approve'}
#
# Event Mapping {'Assess': [['t2: Assess application']], 'Approve': [['t3: Approve']], 'Deny': [['t4: Deny']], 'Register': [['t1: Register application']]}
#
# Stability: True
# Weak Compliance: False
# Counter-examples (4):
#   ('Assess', 'Deny')
#   ('Register', 'Assess', 'Deny')
#   ('Assess', 'Register', 'Deny')
#   ('Assess', 'Register', 'Deny', 'Assess')

# %%
    
interface = WhatIfInterfaceBuilder(goal_model).create_interface()
display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# ## Airline Passenger Rights example

# %% [markdown]
# ### Non-interactive

# %%
goal_model = read_istar_model("Data/air-passenger-rights/goal_model.txt")
petri_net = read_petri_net("Data/air-passenger-rights/petri_net_fail.pnml")
event_mapping = petri_net.get_default_event_mapping()

analyse_models(goal_model, petri_net, event_mapping)
# Out:
# Goal Model LTS reachable states and transitions: (512, 8704)
# Petri Net LTS reachable states and transitions: (13, 16)
# Combined LTS reachable states and transitions: (21, 21)
#
# Goal Model Goals and Tasks: ['Delay at arrival@ measured', 'Claim request@ evaluated', 'Circumstances@ of the delay@ documented', 'Calculate@ delay at arrival', 'Retrieve@ Scheduled@ Arrival Time', 'Retrieve@ Actual Arrival@ Time', "Retrieve time@ of arrival in the@ passenger's@ booking", 'Retrieve time in@ which the doors@ of the aircraft@ were opened', 'Make a@ compensation@ decision', 'Approve@ Compensation', 'Deny@ Compensation', 'Analyze@ Internal@ Systems', 'Document@ additional@ Information for@ Exstraordinary@ circumstances', 'Retrieve@ Information@ Internal@ Systems', 'Document and@ Save File Case', 'Register@ Judgement@ Criteria and@ type of EC', 'Record the@ justification for@ exclusion as an@ extraordinary circumstance']
# Goal Model Qualities: {'Delay at arrival@ measured@ appropriately', 'Extraordinary@ circumstances@ documented@ appropriately'}
#
# Combined LTS Actions: {'t13', 't2', 't15', 't6', 't11', 't4', 't9', 't5', 't8', 't3', 't1', 't12', 't14', 't7'}
#
# Event Mapping {'t14': [['Record the@ justification for@ exclusion as an@ extraordinary circumstance']], 't13': [['Document and@ Save File Case']], 't15': [], 't1': [], 't2': [["Retrieve time@ of arrival in the@ passenger's@ booking"]], 't5': [['Retrieve@ Information@ Internal@ Systems']], 't4': [['Calculate@ delay at arrival']], 't3': [['Retrieve time in@ which the doors@ of the aircraft@ were opened']], 't6': [], 't7': [['Register@ Judgement@ Criteria and@ type of EC']], 't8': [], 't9': [], 't11': [['Deny@ Compensation']], 't12': [['Approve@ Compensation']]}
#
# Stability: True
# Weak Compliance: False
# Counter-examples (3):
#   ('t1', 't2', 't3', 't4', 't15')
#   ('t1', 't2', 't3', 't4', 't15', 't12')
#   ('t1', 't2', 't3', 't4', 't15', 't12', 't13')

# %% [markdown]
# ### Interactive

# %%
goal_model = read_istar_model("Data/air-passenger-rights/goal_model.txt")
petri_net = read_petri_net("Data/air-passenger-rights/petri_net.pnml")
event_mapping = petri_net.get_default_event_mapping()

interface = InterfaceBuilder(goal_model, petri_net, event_mapping=event_mapping).create_interface()
display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# #### Fail: Not Weakly Compliant

# %%
goal_model = read_istar_model("Data/air-passenger-rights/goal_model.txt")
petri_net = read_petri_net("Data/air-passenger-rights/petri_net_fail.pnml")

interface = InterfaceBuilder(goal_model
                             , petri_net
                             , event_mapping=petri_net.get_default_event_mapping()).create_interface()

display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# #### Success: Weakly Compliant and Stable

# %%
goal_model = read_istar_model("Data/air-passenger-rights/goal_model.txt")
petri_net = read_petri_net("Data/air-passenger-rights/petri_net.pnml")
event_mapping = petri_net.get_default_event_mapping()   
interface = InterfaceBuilder(goal_model, petri_net, event_mapping=event_mapping).create_interface()
display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# ## Security example

# %%
goal_model = read_istar_model("Data/security/goal_model.txt")
petri_net = read_petri_net("Data/security/petri_net.pnml")

event_mapping = petri_net.get_default_event_mapping()

analyse_models(goal_model, petri_net, event_mapping=event_mapping)
# Out:
# Goal Model LTS reachable states and transitions: (341, 3751)
# Petri Net LTS reachable states and transitions: (11, 13)
# Combined LTS reachable states and transitions: (24, 26)
#
# Goal Model Goals and Tasks: ['Data Breach Detected', 'Data Protected', 'Apply Vulnerability Patch', 'Perform Penetration Tests', 'Flag Suspicious Activity', 'Deploy DataGrail', 'Deploy OneTrust', 'Revise Access Controls', 'Update Encryption Standards', 'Implement Password Policy', 'Deploy Monitoring Tools']
# Goal Model Qualities: {'Data Protected Appropriately'}
#
# Combined LTS Actions: {'t_8', 't_1', 't_2', 't_9', 't_7', 't_10', 't_3', 't_5', 't_4', 't_11', 't_6'}
#
# Event Mapping {'t_11': [['Apply Vulnerability Patch']], 't_1': [], 't_5': [['Deploy DataGrail']], 't_4': [], 't_2': [['Update Encryption Standards']], 't_3': [['Revise Access Controls']], 't_6': [['Deploy OneTrust']], 't_7': [], 't_8': [['Perform Penetration Tests']], 't_9': [], 't_10': [['Flag Suspicious Activity']]}
#
# Stability: False
# Counter-examples (4):
#   ('t_1', 't_2', 't_3', 't_4', 't_5', 't_7', 't_8', 't_10')
#   ('t_1', 't_2', 't_3', 't_4', 't_6', 't_7', 't_8', 't_10')
#   ('t_1', 't_2', 't_3', 't_4', 't_6', 't_7', 't_8', 't_10', 't_11', 't_8', 't_10')
#   ('t_1', 't_2', 't_3', 't_4', 't_5', 't_7', 't_8', 't_10', 't_11', 't_8', 't_10')
# Weak Compliance: True

# %%
goal_model = read_istar_model("Data/security/goal_model.txt")
petri_net = read_petri_net("Data/security/petri_net.pnml")
event_mapping = petri_net.get_default_event_mapping()

interface = InterfaceBuilder(goal_model, petri_net, event_mapping=event_mapping).create_interface()
display(interface)
# Out:
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# ### Failing Weak compliance in the security example
# Weak compliance can fail, if an intentional element of the goal model is not mapped to a transition in the event mapping.

# %%
goal_model = read_istar_model("Data/security/goal_model.txt")
petri_net = read_petri_net("Data/security/petri_net.pnml")

event_mapping = petri_net.get_default_event_mapping()
event_mapping.update({"t_6":[]}) # remove the mapping for t6 to show failing weak compliance

analyse_models(goal_model, petri_net, event_mapping=event_mapping)

interface = InterfaceBuilder(goal_model, petri_net, event_mapping=event_mapping).create_interface()
display(interface)
# Out:
# Goal Model LTS reachable states and transitions: (341, 3751)
# Petri Net LTS reachable states and transitions: (11, 13)
# Combined LTS reachable states and transitions: (24, 26)
#
# Goal Model Goals and Tasks: ['Data Breach Detected', 'Data Protected', 'Apply Vulnerability Patch', 'Perform Penetration Tests', 'Flag Suspicious Activity', 'Deploy DataGrail', 'Deploy OneTrust', 'Revise Access Controls', 'Update Encryption Standards', 'Implement Password Policy', 'Deploy Monitoring Tools']
# Goal Model Qualities: {'Data Protected Appropriately'}
#
# Combined LTS Actions: {'t_8', 't_1', 't_2', 't_9', 't_7', 't_10', 't_3', 't_5', 't_4', 't_11', 't_6'}
#
# Event Mapping {'t_1': [], 't_2': [['Update Encryption Standards']], 't_5': [['Deploy DataGrail']], 't_4': [], 't_3': [['Revise Access Controls']], 't_6': [], 't_7': [], 't_8': [['Perform Penetration Tests']], 't_9': [], 't_10': [['Flag Suspicious Activity']], 't_11': [['Apply Vulnerability Patch']]}
#
# Stability: False
# Counter-examples (3):
#   ('t_1', 't_2', 't_3', 't_4', 't_5', 't_7', 't_8', 't_10')
#   ('t_1', 't_2', 't_3', 't_4', 't_6', 't_7', 't_8', 't_10', 't_11', 't_8', 't_10')
#   ('t_1', 't_2', 't_3', 't_4', 't_5', 't_7', 't_8', 't_10', 't_11', 't_8', 't_10')
# Weak Compliance: False
# Counter-examples (1):
#   ('t_1', 't_2', 't_3', 't_4', 't_6', 't_7', 't_8', 't_9')
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# ## Shop example
#
# A simple shop example. It is stable, because the quality "Ensure Customer Satisfaction" is satisfied in the last state, and the quality "Minimize Cost" is never satisfied.
#
# The example is not weakly compliant, as the "Minimize Cost" quality is never satisfied.

# %%
goal_model = read_istar_model("Data/shop/goal_model.txt")
petri_net = read_petri_net("Data/shop/petri_net.pnml")

event_mapping = petri_net.get_default_event_mapping()

analyse_models(goal_model, petri_net, event_mapping=event_mapping)

interface = InterfaceBuilder(goal_model, petri_net).create_interface()
display(interface)
# Out:
# Goal Model LTS reachable states and transitions: (8, 40)
# Petri Net LTS reachable states and transitions: (4, 3)
# Combined LTS reachable states and transitions: (4, 3)
#
# Goal Model Goals and Tasks: ['Fulfill Order', 'Deliver on Time', 'Pick Items', 'Pack Items', 'Ship Items']
# Goal Model Qualities: {'Ensure Customer Satisfaction', 'Minimize Cost'}
#
# Combined LTS Actions: {'t3', 't1', 't2'}
#
# Event Mapping {'t1': [['Pick Items']], 't3': [['Ship Items']], 't2': [['Pack Items']]}
#
# Stability: True
# Weak Compliance: False
# Counter-examples (4):
#   ()
#   ('t1',)
#   ('t1', 't2')
#   ('t1', 't2', 't3')
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…
