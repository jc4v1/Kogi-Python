# %% [markdown]
# ## Required imports

# %%
from Semantics.istar_processor import read_istar_model
from Semantics.petri_net_processor import read_petri_net
from Semantics.event_mapping_from_csv import read_event_mapping_csv, event_mapping_for_petri_net
from Ui.interface import InterfaceBuilder
from Ui.interface import WhatIfInterfaceBuilder
from Semantics.transition_system import combine_goal_model_and_petri_net
from Semantics.transition_system import CombinedTransitionSystem
from scripts.sanitize_pnml import sanitize

# %% [markdown]
# ## Airline Passenger Rights example

# %%
goal_model = read_istar_model("Data/airline/pretty/airline_gm.txt")
petri_net = read_petri_net("Data/airline/pretty/airline_pn_fail.pnml")
event_mapping = petri_net.get_default_event_mapping()

lts_gm = goal_model.as_transition_system()
print(f"Goal Model LTS reachable states and transitions: {lts_gm.size()}")

lts_pn = petri_net.as_transition_system()
print(f"Petri Net LTS reachable states and transitions: {lts_pn.size()}")

lts_combined = CombinedTransitionSystem(lts_gm, lts_pn, event_mapping)
print(f"Combined LTS reachable states and transitions: {lts_combined.size()}")

results = lts_combined.check_stability(goal_model.qualities)
print(f"Stability: {results[0]}")
print(f"Counterexamples: {len(results[1])}")

result = lts_combined.check_weak_compliance(goal_model.qualities)
print(f"Weak Compliance: {result[0]}")
print(f"Counterexamples: {len(result[1])}")

# %%
map = read_event_mapping_csv("Data/test.csv")
print(map)

# %% [markdown]
# ### Fail

# %%
goal_model = read_istar_model("Data/airline/pretty/airline_gm.txt")
petri_net = read_petri_net("Data/airline/pretty/airline_pn_fail.pnml")

interface = InterfaceBuilder(goal_model
                             , petri_net
                             , event_mapping=petri_net.get_default_event_mapping()
                             , debug=True).create_interface()

display(interface)

# %% [markdown]
# ### Success

# %%
goal_model = read_istar_model("Data/airline/pretty/airline_gm.txt")
petri_net = read_petri_net("Data/airline/pretty/airline_pn.pnml")

print("Goal Model:"+str(goal_model.size()))
print("Petri Net:"+str(petri_net.size()))

petri_net.set_event_mapping(goal_model)

interface = InterfaceBuilder(goal_model, petri_net, debug=True).create_interface()
display(interface)

# %% [markdown]
# ## Security example from the paper

# %%
goal_model = read_istar_model("Data/pretty/example_from_paper.txt")
petri_net = read_petri_net("Data/pretty/demo.pnml")

petri_net.set_event_mapping(goal_model)

combine_goal_model_and_petri_net(goal_model, petri_net, event_mapping = None)

# %%
goal_model = read_istar_model("Data/pretty/example_from_paper.txt")
petri_net = read_petri_net("Data/pretty/demo.pnml")

petri_net.set_event_mapping(goal_model)

interface = InterfaceBuilder(goal_model, petri_net, debug=True).create_interface()
display(interface)

# %%
goal_model = read_istar_model("Data/pretty/example_from_paper.txt")
petri_net = read_petri_net("Data/pretty/demo.pnml")

petri_net.set_event_mapping(goal_model)

interface = InterfaceBuilder(goal_model, petri_net, debug=True).create_interface()
display(interface)

# %% [markdown]
# ### Failing Weak compliance in the security example from the paper
# As the paper discusses, weak compliance can fail, if an intentional element of the goal model is not mapped to a transition in the event mapping.

# %%
goal_model = read_istar_model("Data/pretty/example_from_paper.txt")
petri_net = read_petri_net("Data/pretty/demo.pnml")

petri_net.set_event_mapping(goal_model)

goal_model.add_event_mapping("t_6",[]) # remove the mapping for t6 to show failing weak compliance

interface = InterfaceBuilder(goal_model, petri_net, debug=True).create_interface()
display(interface)

# %% [markdown]
# ## Shop example

# %% [markdown]
# A simple shop example. It is stable, because the quality "Ensure Customer Satisfaction" is satisfied in the last state, and the quality "Minimize Cost" is never satisfied.
#
# The example is not weakly compliant, as the "Minimize Cost" quality is never satisfied.

# %%
goal_model = read_istar_model("Data/shop.txt")
petri_net = read_petri_net("Data/shop.pnml")

petri_net.set_event_mapping(goal_model)

interface = InterfaceBuilder(goal_model, petri_net, debug=True).create_interface()
display(interface)

# %% [markdown]
# ## What if scenario

# %% [markdown]
# The what-if scenario only looks at the behaviour of the goal model, and how the goal model reacts to
# when tasks or goals are activated. In this animation, goals and tasks that don't have a
# refinement, can be selected in any order.
#
# This allows to experiment with possible scenarios on how to achieve the goals of the
# goal model or to make or break its qualities.

# %% [markdown]
# The first step is to create a goal model with [PiStar](https://www.cin.ufpe.br/~jhcp/pistar/tool/#), move the file goal_model.txt in the Download folder to the right place and the right
# name, and then read the file.
#
# And then create the interface with the InterfaceBuilder class, and diplay the created interface.

# %%
goal_model = read_istar_model("Data/what_if_gm.txt")
petri_net = goal_model.generate_all_events_petri_net()

combine_goal_model_and_petri_net(goal_model, petri_net, event_mapping = None)

# %%
gm = read_istar_model("Data/what_if_gm.txt")

interface = InterfaceBuilder(gm, whatif=True).create_interface()
display(interface)

# %% [markdown]
# What happens is, that in the background a Petri net is created. That Petri net
# has one place and a transition from and to that place for each task and goal that
# does not have a refinement. This allows to select and execute those tasks and goals in any order.
#
# Here is an example of the Petri net for two events e1 and e2.
#
# ![petri net](Data/all-events-pn.png)

# %%
goal_model = read_istar_model("Data/test/simple.txt")
petri_net = goal_model.generate_all_events_petri_net()

combine_goal_model_and_petri_net(goal_model, petri_net, event_mapping = None)

# %%
gm = read_istar_model("Data/test/simple.txt")

interface = InterfaceBuilder(gm, whatif=True).create_interface()
display(interface)

# %%
goal_model = read_istar_model("Data/test/simple2.txt")
petri_net = goal_model.generate_all_events_petri_net()

combine_goal_model_and_petri_net(goal_model, petri_net, event_mapping = None)

# %%
gm = read_istar_model("Data/test/simple2.txt")

interface = InterfaceBuilder(gm, whatif=True).create_interface()
display(interface)

# %%
goal_model = read_istar_model("Data/test/simple.txt")
petri_net = read_petri_net("Data/test/pn.pnml")

petri_net.set_event_mapping(goal_model)

combine_goal_model_and_petri_net(goal_model, petri_net, event_mapping = goal_model.event_mapping)

# %% [markdown]
# ## Your own example

# %% [markdown]
# Choose your process model and goal model. You can use the following tools
# - For Petri Nets https://www.fernuni-hagen.de/ilovepetrinets/fapra/wise23/rot/index.html
#   - If you add actions to transitions in the petri net editor; they will be automatically mapped to intentional elements in the goal model using
#   - ``petri_net.set_event_mapping(goal_model)``
# - For Goal models https://www.cin.ufpe.br/~jhcp/pistar/tool/#

# %%
goal_model = read_istar_model("your_goal_model.txt")
petri_net = read_petri_net("your_petri_net.pnml")

petri_net.set_event_mapping(goal_model)

interface = InterfaceBuilder(goal_model, petri_net, debug=True).create_interface()
display(interface)

# %% [markdown]
# ## BPMN example

# %% [markdown]
# ![BPMN process model](Data/bpmn/process_model.jpg)

# %% [markdown]
# ![Goal Model](Data/bpmn/goal_model.png)

# %%
import pm4py
from Semantics.petri_net import PetriNet
from pm4py.objects.petri_net.exporter import exporter as pnml_exporter
from Semantics.goal_model import GoalModel

goal_model = read_istar_model("Data/bpmn/goal_model.txt")
print("Events "+str(goal_model.all_events()))
bpmn_model = pm4py.read_bpmn("Data/bpmn/process_model.bpmn")

petri_net = read_petri_net("Data/bpmn/petri_net_from_bpmn_sanitized_with_positions.pnml")
print("Transitions in Petri Net: "+repr(petri_net.net.transitions))

event_map = read_event_mapping_csv("Data/bpmn/map.csv")
event_mapping = event_mapping_for_petri_net(event_map, petri_net)
# event_mapping = petri_net.get_default_event_mapping()
print(event_mapping)

interface = InterfaceBuilder(goal_model
                             , petri_net
                             , event_mapping=event_mapping
                             , debug=True).create_interface()
display(interface)
# Out:
# Events ['G1', 'G2', 'G3', 'T1', 'T2', 'T4', 'T5', 'T6', 'T7', 'T8', 'T3']
# Transitions in Petri Net: {(t1, 'e4'), (t2, 'e5'), (t4, 'e7'), (t3, 'e2'), (t5, 'e1'), (t6, 'e8'), (t7, 'e3'), (t8, 'e6')}
# {'t1': [['T4']], 't2': [['T5']], 't4': [['T7']], 't3': [['T2']], 't5': [['T1']], 't6': [['T8']], 't7': [['T3']], 't8': [['T6']]}
# DEBUG: safe_update_visualization() called - Starting render
# Current petri_tokens: {'p1': 1}
# DEBUG: safe_update_visualization() completed - Render finished
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %%
import pm4py
from Semantics.petri_net import PetriNet
from pm4py.objects.petri_net.exporter import exporter as pnml_exporter
from Semantics.goal_model import GoalModel

goal_model = read_istar_model("Data/bpmn/goal_model.txt")
print("Events "+str(goal_model.all_events()))
bpmn_model = pm4py.read_bpmn("Data/bpmn/process_model.bpmn")

# Convert BPMN to Petri Net
net, init, final = pm4py.convert_to_petri_net(bpmn_model)
pnml_exporter.apply(net, init, "Data/bpmn/petri_net_from_bpmn.pnml")
sanitize("Data/bpmn/petri_net_from_bpmn.pnml", "Data/bpmn/petri_net_from_bpmn_sanitized.pnml")    
petri_net = read_petri_net("Data/bpmn/petri_net_from_bpmn_sanitized.pnml")
print("Transitions in Petri Net: "+repr(petri_net.net.transitions))

event_map = read_event_mapping_csv("Data/bpmn/map.csv")
event_mapping = event_mapping_for_petri_net(event_map, petri_net)
# event_mapping = petri_net.get_default_event_mapping()
print(event_mapping)

lts_gm = goal_model.as_transition_system()
print(f"Goal Model LTS reachable states and transitions: {lts_gm.size()}")

lts_pn = petri_net.as_transition_system()
print(f"Petri Net LTS reachable states and transitions: {lts_pn.size()}")

lts_combined = CombinedTransitionSystem(lts_gm, lts_pn, event_mapping)
print(f"Combined LTS reachable states and transitions: {lts_combined.size()}")

results = lts_combined.check_stability(goal_model.qualities)
print(f"Stability: {results[0]}")
print(f"Conterexamples: {len(results[1])}")

result = lts_combined.check_weak_compliance(goal_model.qualities)
print(f"Weak Compliance: {result[0]}")
print(f"Counterexamples: {len(result[1])}")
# Out:
# Events ['G1', 'G2', 'G3', 'T1', 'T2', 'T4', 'T5', 'T6', 'T7', 'T8', 'T3']
# Transitions in Petri Net: {(t1, 'e7'), (t2, 'e3'), (t3, 'e5'), (t4, 'e6'), (t5, 'e4'), (t6, 'e1'), (t7, 'e8'), (t8, 'e2')}
# {'t1': [['T7']], 't2': [['T3']], 't3': [['T5']], 't4': [['T6']], 't5': [['T4']], 't6': [['T1']], 't7': [['T8']], 't8': [['T2']]}
# Goal Model LTS reachable states and transitions: (369, 4059)
# Petri Net LTS reachable states and transitions: (9, 10)
# Combined LTS reachable states and transitions: (10, 10)
# Stability: False
# Conterexamples: 3
# Weak Compliance: False
# Counterexamples: 4

# %%
goal_model = read_istar_model("Data/bpmn/goal_model.txt")

interface = WhatIfInterfaceBuilder(goal_model).create_interface()
display(interface)

# %% [markdown]
# ## Running Example

# %% [markdown]
# Petri Net
#
# ![Petri Net](Data/example/petri_net.png)

# %% [markdown]
# Goal Model
#
# ![Goal Model](Data/example/goal_model.jpg)

# %% [markdown]
# Event Mapping
#
# ![Event Mapping](Data/example/map.jpg)

# %% [markdown]
# ### Non-Interactice

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")
print("Events "+str(goal_model.all_events()))

petri_net = read_petri_net("Data/example/petri_net.pnml")
print("Transitions in Petri Net: "+repr(petri_net.net.transitions))

event_mapping = read_event_mapping_csv("Data/example/map.csv")
print(event_mapping)

lts_gm = goal_model.as_transition_system()
print(f"Goal Model LTS reachable states and transitions: {lts_gm.size()}")

lts_pn = petri_net.as_transition_system()
print(f"Petri Net LTS reachable states and transitions: {lts_pn.size()}")

lts_combined = CombinedTransitionSystem(lts_gm, lts_pn, event_mapping)
print(f"Combined LTS reachable states and transitions: {lts_combined.size()}")

results = lts_combined.check_stability(goal_model.qualities)
print(f"Stability: {results[0]}")
print(f"Conterexamples: {len(results[1])}")

result = lts_combined.check_weak_compliance(goal_model.qualities)
print(f"Weak Compliance: {result[0]}")
print(f"Counterexamples: {len(result[1])}")
# Out:
# Events ['Required documentation received', 'Application assessed', 'Decision-making completed', 'Application closed', 'Receive application', 'Assess application', 'Approve', 'Deny']
# Transitions in Petri Net: {(t1, 't1'), (t2, 'Register'), (t3, 'Assess'), (t4, 't4'), (t5, 't5'), (t6, 'Approve'), (t8, 't8'), (t7, 'Deny')}
# {'t1': [], 't2': [['Receive application']], 't3': [['Assess application']], 't4': [], 't5': [], 't6': [['Approve']], 't7': [['Deny']], 't8': []}
# Goal Model LTS reachable states and transitions: (20, 160)
# Petri Net LTS reachable states and transitions: (7, 8)
# Combined LTS reachable states and transitions: (11, 11)
# Stability: True
# Conterexamples: 0
# Weak Compliance: False
# Counterexamples: 2

# %% [markdown]
# ### Interactive

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")
petri_net = read_petri_net("Data/example/petri_net.pnml")
event_mapping = read_event_mapping_csv("Data/example/map.csv")

interface = InterfaceBuilder(goal_model,petri_net=petri_net,event_mapping=event_mapping,debug=True).create_interface()
display(interface)
# Out:
# DEBUG: safe_update_visualization() called - Starting render
# Current petri_tokens: {'p1': 1}
# DEBUG: safe_update_visualization() completed - Render finished
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %% [markdown]
# ### WhatIf Scenario

# %%
goal_model = read_istar_model("Data/example/goal_model.txt")

interface = WhatIfInterfaceBuilder(goal_model).create_interface()
display(interface)

# %% [markdown]
# ### Updated Version

# %%
goal_model = read_istar_model("Data/example2/goal_model.txt")
print("Tasks and Goals "+str(goal_model.all_events()))
print()

pn = read_petri_net("Data/example2/petri_net.pnml")
print("Not sanitized Petri net transitons "+repr(pn.net.transitions))
print()

sanitize("Data/example2/petri_net.pnml", "Data/example2/petri_net_sanitized.pnml")    
petri_net = read_petri_net("Data/example2/petri_net_sanitized.pnml")
print("SanitizedPetri net transitons "+repr(petri_net.net.transitions))
print()

event_mapping = read_event_mapping_csv("Data/example2/map.csv")
# event_mapping = petri_net.get_default_event_mapping()
print("Event mapping: "+str(event_mapping))
print()

lts_gm = goal_model.as_transition_system()
print(f"Goal Model LTS reachable states and transitions: {lts_gm.size()}")

lts_pn = petri_net.as_transition_system()
print(f"Petri Net LTS reachable states and transitions: {lts_pn.size()}")

lts_combined = CombinedTransitionSystem(lts_gm, lts_pn, event_mapping)
print(f"Combined LTS reachable states and transitions: {lts_combined.size()}")

results = lts_combined.check_stability(goal_model.qualities)
print(f"Stability: {results[0]}")
print(f"Conterexamples: {len(results[1])}")

result = lts_combined.check_weak_compliance(goal_model.qualities)
print(f"Weak Compliance: {result[0]}")
print(f"Counterexamples: {len(result[1])}")
# Out:
# Tasks and Goals ['g:4 Application closed', 'g1: Required documentation registered', 'g:2 Application assessed', 'g:3 Decision-making completed', 't1: Register application', 't4: Deny', 't2: Assess application', 't3: Approve']
#
# Not sanitized Petri net transitons {(c6012c6c-de62-4816-b648-1c8fab475996, None), (sid-E31BA18A-6819-47D9-9F43-212802C0EBF1, None), (sid-4C64C44C-BFA3-49BF-A62C-E60F5ED9702E, 'Deny'), (sid-DC65CE4D-B992-420A-8F1F-3AB802F48031, 'Approve'), (sid-6FDFE430-21F7-4796-BFEA-2B43E272956A, 'Assess'), (sfl_sid-867B630A-CCD2-40CD-9532-46D0CC102A59, None), (sfl_sid-54C2D0E6-635F-461C-9395-91E600D3E54B, None), (sid-1FA5F322-AF77-40A2-A70A-A143E42996C5, 'Register')}
#
# SanitizedPetri net transitons {(t1, None), (t2, 'Assess'), (t3, 'Approve'), (t4, None), (t5, 'Deny'), (t6, None), (t7, None), (t8, 'Register')}
#
# Event mapping: {'t1': [], 't2': [['t2: Assess application']], 't3': [['t3: Approve']], 't4': [], 't5': [['t4: Deny']], 't6': [], 't7': [], 't8': [['t1: Register application']]}
#
# Goal Model LTS reachable states and transitions: (20, 160)
# Petri Net LTS reachable states and transitions: (7, 8)
# Combined LTS reachable states and transitions: (11, 11)
# Stability: True
# Conterexamples: 0
# Weak Compliance: False
# Counterexamples: 2

# %%
goal_model = read_istar_model("Data/example2/goal_model.txt")
petri_net = read_petri_net("Data/example2/petri_net_with_positions.pnml")
event_mapping = read_event_mapping_csv("Data/example2/map.csv")

interface = InterfaceBuilder(goal_model,petri_net=petri_net,event_mapping=event_mapping,debug=True).create_interface()
display(interface)
# Out:
# DEBUG: safe_update_visualization() called - Starting render
# Current petri_tokens: {'p5': 1}
# DEBUG: safe_update_visualization() completed - Render finished
# VBox(children=(HTML(value="\n        <div style='text-align: center; margin-bottom: 20px;'>\n            <h1 s…

# %%
from Semantics.dcr import load_dcr_as_ts
ts = load_dcr_as_ts('Data/example2/dcr.xml')
print(type(ts))
print("Initial State: ")
print(ts.initial_state())
print()
print(ts.size())               # (num_states, num_transitions)
print("Enabled Actions: ")
print(ts.get_enabled_actions(ts.initial_state()))
print("States")
for state in ts.states():
    print(repr(state))
print("Transitions: ")
for s, action_dict in ts.transitions.items():
    for action, next_states in action_dict.items():
        print(f"{s} --{action}--> {next_states}")
# Out:
# <class 'Semantics.transition_system.TransitionSystem'>
# Initial State:
# DcrMarking(exe=[], inc=['Approve', 'Assess', 'Deny', 'Register'], pen=[])
#
# (16, 32)
# Enabled Actions:
# ['Register']
# States
# DcrMarking(exe=['Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])
# DcrMarking(exe=[], inc=['Approve', 'Assess', 'Deny', 'Register'], pen=[])
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Register'], pen=[])
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Register'], pen=[])
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Register'], pen=[])
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Assess'], pen=['Assess'])
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])
# Transitions:
# DcrMarking(exe=[], inc=['Approve', 'Assess', 'Deny', 'Register'], pen=[]) --Register--> {DcrMarking(exe=['Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}
# DcrMarking(exe=['Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Deny--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Register--> {DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Register'], pen=[]) --Register--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Register'], pen=[]) --Register--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Deny--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Deny--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Deny--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Assess'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Deny--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Register--> {DcrMarking(exe=['Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Deny--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Register--> {DcrMarking(exe=['Approve', 'Assess', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Register'], pen=[]) --Register--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Deny--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Assess'], pen=['Assess'])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess']) --Assess--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Deny--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Approve--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Register'], pen=[])}
# DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Deny', 'Register'], pen=[]) --Register--> {DcrMarking(exe=['Approve', 'Assess', 'Deny', 'Register'], inc=['Approve', 'Assess', 'Deny'], pen=['Assess'])}

# %%
from Semantics.dcr import load_dcr_as_ts
ts = load_dcr_as_ts('Data/test/dcr1.xml')
print(type(ts))
print("Initial State: ")
print(ts.initial_state())
print()
print(ts.size())               # (num_states, num_transitions)
print("Enabled Actions: ")
print(ts.get_enabled_actions(ts.initial_state()))
print("States")
for state in ts.states():
    print(repr(state))
print("Transitions: ")
for s, action_dict in ts.transitions.items():
    for action, next_states in action_dict.items():
        print(f"{s} --{action}--> {next_states}")
# Out:
# <class 'Semantics.transition_system.TransitionSystem'>
# Initial State:
# DcrMarking(exe=[], inc=['A', 'B'], pen=[])
#
# (3, 5)
# Enabled Actions:
# ['A']
# States
# DcrMarking(exe=['A', 'B'], inc=['A', 'B'], pen=[])
# DcrMarking(exe=[], inc=['A', 'B'], pen=[])
# DcrMarking(exe=['A'], inc=['A', 'B'], pen=[])
# Transitions:
# DcrMarking(exe=[], inc=['A', 'B'], pen=[]) --A--> {DcrMarking(exe=['A'], inc=['A', 'B'], pen=[])}
# DcrMarking(exe=['A'], inc=['A', 'B'], pen=[]) --A--> {DcrMarking(exe=['A'], inc=['A', 'B'], pen=[])}
# DcrMarking(exe=['A'], inc=['A', 'B'], pen=[]) --B--> {DcrMarking(exe=['A', 'B'], inc=['A', 'B'], pen=[])}
# DcrMarking(exe=['A', 'B'], inc=['A', 'B'], pen=[]) --A--> {DcrMarking(exe=['A', 'B'], inc=['A', 'B'], pen=[])}
# DcrMarking(exe=['A', 'B'], inc=['A', 'B'], pen=[]) --B--> {DcrMarking(exe=['A', 'B'], inc=['A', 'B'], pen=[])}

# %%
from Semantics.dcr import load_dcr_as_ts
goal_model = read_istar_model("Data/example2/goal_model.txt")
print("Tasks and Goals "+str(goal_model.all_events()))
print()

lts_dcr = load_dcr_as_ts("Data/example2/dcr.xml")
# print("DCR "+repr(lts_dcr.transitions))
print("DCR Actions "+str(lts_dcr.actions()))

event_mapping = read_event_mapping_csv("Data/example2/dcr_map.csv")
print("Event mapping: "+str(event_mapping))
print()

lts_gm = goal_model.as_transition_system()
print(f"Goal Model LTS reachable states and transitions: {lts_gm.size()}")

print(f"DCR LTS reachable states and transitions: {lts_dcr.size()}")

lts_combined = CombinedTransitionSystem(lts_gm, lts_dcr, event_mapping)
print(f"Combined LTS reachable states and transitions: {lts_combined.size()}")

results = lts_combined.check_stability(goal_model.qualities)
print(f"Stability: {results[0]}")
print(f"Conterexamples: {len(results[1])}")

result = lts_combined.check_weak_compliance(goal_model.qualities)
print(f"Weak Compliance: {result[0]}")
print(f"Counterexamples: {len(result[1])}")
# Out:
# Tasks and Goals ['g:4 Application closed', 'g1: Required documentation registered', 'g:2 Application assessed', 'g:3 Decision-making completed', 't1: Register application', 't4: Deny', 't2: Assess application', 't3: Approve']
#
# DCR Actions {'Assess', 'Register', 'Approve', 'Deny'}
# Event mapping: {'Assess': [['t2: Assess application']], 'Approve': [['t3: Approve']], 'Deny': [['t4: Deny']], 'Register': [['t1: Register application']]}
#
# Goal Model LTS reachable states and transitions: (20, 160)
# DCR LTS reachable states and transitions: (16, 32)
# Combined LTS reachable states and transitions: (20, 40)
# Stability: False
# Conterexamples: 8
# Weak Compliance: True
# Counterexamples: 0
