# %% [markdown]
# # Kogi Tool
#
# **Here is a <a href="https://youtu.be/nlm7nSgGy0g" target="_blank">video</a> showing how to use Kogi.**
#
# Recommended model editors:
# - Goal Model: <a href="https://www.istardust.ch/" target="_blank">piStar</a>
# - Petri Net: <a href="https://www.fernuni-hagen.de/ilovepetrinets/fapra/wise23/rot/index.html" target="_blank">I love Petri Nets</a>
# - DCR Graph: <a href="https://hugoalopez-dtu.github.io/dcr-js/" target="_blank">DCR Graph-JS</a> (download and upload as DCR Solutions XML)
# - BPMN: <a href="https://bpmn.io/" target="_blank">BPMN.io</a>
#
# You can download a zip file with test models: <a href='https://www.imm.dtu.dk/~huba/Data.zip' target='_blank'>Data.zip</a>
#
# Usage:
# - The goal model is required. If only the goal model is selected, the What If interface is shown
# - For a goal model plus a DCR Graph or BPMN model, the non-interactive analysis is run after which the What If interface is shown.
#   - Both also require a mapping to be uploaded.
# - For Petri Nets there is a choice to choose the interactive mode or the non-interactive mode by having the check box slected or not. This basically depends on if the Petri Net has position information for places and transitions. This is required by the interactive mode.
#   - For Petri nets, the map can be omitted, if the actions in the Petri net correspond to intensional element names of the goal model.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
from Ui.interface import FileUploadInterfaceBuilder
display(FileUploadInterfaceBuilder().create_interface())
